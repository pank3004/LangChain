# %% [markdown]
# ## 1 DuckDuckGo Search

# %%
! pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.6.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from ddgs) (8.3.0)
# Collecting primp>=0.15.0 (from ddgs)
#   Downloading primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Collecting lxml>=6.0.0 (from ddgs)
#   Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: colorama in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.11.0)
# Requirement already satisfied: certifi in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: brotli in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\91830\anaconda3\envs\genaienv\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.6.1-py3-none-any.whl (41 kB)
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
# Downloading primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ----------------------------- ---------- 2.4/3.1 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 11.6 MB/s  0:00:00
# Installing collected packages: socksio, primp, lxml, ddgs
#
#    ---------- ----------------------------- 1/4 [primp]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    ------------------------------ --------- 3/4 [ddgs]
#    ------------------------------ --------- 3/4 [ddgs]
#    ---------------------------------------- 4/4 [ddgs]
#
# Successfully installed ddgs-9.6.1 lxml-6.0.2 primp-0.15.0 socksio-1.0.0

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool=DuckDuckGoSearchRun()
results=search_tool.invoke('top 5 news today in india')
print(results)
# Out:
# Get the latest updates and breaking news from India , including politics, elections, government, business, technology, and Bollywood. Zee News brings latest news from India and World on breaking news , today news headlines, politics, business, technology, bollywood, entertainment, sports and others. Find exclusive news stories on Indian politics, current affairs, cricket matches, festivals and events India's Top Breaking News Live: Police tighten surveillance in tourist areas Authorities have pledged to continue surprise inspections, using NDPS kits to check for contraband, and have booked ten ... Stay informed with the latest top headlines and breaking news from India and worldwide. Get live updates on the biggest stories in politics, sports, business, and entertainment. Reuters.com is your online source for the latest India news stories and current events, ensuring our readers up to date with any breaking news developments

# %% [markdown]
# ## 2 Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool=ShellTool()
results=shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# laptop-rh5tn4va\91830
# c:\Users\91830\anaconda3\envs\genaienv\lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
